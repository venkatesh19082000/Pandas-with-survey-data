# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Venkatesh\Downloads\survey_results_public.csv')
df1=pd.read_csv(r'C:\Users\Venkatesh\Downloads\survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df1.shape
# Out:
# (79, 6)

# %%
df1
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.set_index('ResponseId',inplace=True)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 73264                          I am a developer by profession
# 73265                          I am a developer by profession
# 73266       I am not primarily a developer, but I write co...
# 73267                          I am a developer by profession
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# ...

# %%
df.loc[0:5,'CodingActivities':'LearnCodeCoursesCert']
# Out:
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
# 4                       I don’t code outside of work
# 5                                              Hobby
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# 2                                                       NaN
# 3           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# ...

# %%
df.loc[0:5,['CodingActivities']]
# Out:
#                                     CodingActivities
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
# 4                       I don’t code outside of work
# 5                                              Hobby

# %%
df.iloc[[4,5],[2,3,4]]
# Out:
#                                       RemoteWork CodingActivities  \
# ResponseId
# 5           Hybrid (some remote, some in-person)            Hobby
# 6                                            NaN              NaN
#
#                                                     EdLevel
# ResponseId
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,['LanguageHaveWorkedWith']]
# Out:
#                                        LanguageHaveWorkedWith
# ResponseId
# 3                           C#;C++;HTML/CSS;JavaScript;Python
# 7               C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15                HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                       C#;Java;PHP;Python;R
# ...                                                       ...
# 73258                                            C;Python;SQL
# 73262       Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73264       Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265               Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                      HTML/CSS;JavaScript;PHP;Python;SQL
#
# [34155 rows x 1 columns]

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
Countries=['India','Canada','Germany']
filt=df['Country'].isin(Countries)
df[filt]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                              I am a developer by profession
# 6           I am not primarily a developer, but I write co...
# 7                                 I code primarily as a hobby
# 8                              I am a developer by profession
# 23                             I am a developer by profession
# ...                                                       ...
# 73256                          I am a developer by profession
# 73258                                   I am learning to code
# 73259                          I am a developer by profession
# 73263                                   I am learning to code
# 73268       I used to be a developer by profession, but no...
#
#                                                    Employment  \
# ResponseId
# 2                                         Employed, full-time
# 6                                          Student, full-time
# ...

# %%
Countries=['India','Canada','Germany']
filt=df['Country'].isin(Countries)
df.loc[filt,['Country','ConvertedCompYearly']]
# Out:
#             Country  ConvertedCompYearly
# ResponseId
# 2            Canada                  NaN
# 6           Germany                  NaN
# 7             India                  NaN
# 8             India                  NaN
# 23           Canada              97605.0
# ...             ...                  ...
# 73256         India                  NaN
# 73258         India                  NaN
# 73259         India                  NaN
# 73263       Germany                  NaN
# 73268        Canada                  NaN
#
# [14524 rows x 2 columns]

# %%
df.columns=[x.upper() for x in df.columns]

# %%
df.columns
# Out:
# Index(['MAINBRANCH', 'EMPLOYMENT', 'REMOTEWORK', 'CODINGACTIVITIES', 'EDLEVEL',
#        'LEARNCODE', 'LEARNCODEONLINE', 'LEARNCODECOURSESCERT', 'YEARSCODE',
#        'YEARSCODEPRO', 'DEVTYPE', 'ORGSIZE', 'PURCHASEINFLUENCE', 'BUYNEWTOOL',
#        'COUNTRY', 'CURRENCY', 'COMPTOTAL', 'COMPFREQ',
#        'LANGUAGEHAVEWORKEDWITH', 'LANGUAGEWANTTOWORKWITH',
#        'DATABASEHAVEWORKEDWITH', 'DATABASEWANTTOWORKWITH',
#        'PLATFORMHAVEWORKEDWITH', 'PLATFORMWANTTOWORKWITH',
#        'WEBFRAMEHAVEWORKEDWITH', 'WEBFRAMEWANTTOWORKWITH',
#        'MISCTECHHAVEWORKEDWITH', 'MISCTECHWANTTOWORKWITH',
#        'TOOLSTECHHAVEWORKEDWITH', 'TOOLSTECHWANTTOWORKWITH',
#        'NEWCOLLABTOOLSHAVEWORKEDWITH', 'NEWCOLLABTOOLSWANTTOWORKWITH',
#        'OPSYSPROFESSIONAL USE', 'OPSYSPERSONAL USE', 'VERSIONCONTROLSYSTEM',
#        'VCINTERACTION', 'VCHOSTINGPERSONAL USE', 'VCHOSTINGPROFESSIONAL USE',
#        'OFFICESTACKASYNCHAVEWORKEDWITH', 'OFFICESTACKASYNCWANTTOWORKWITH',
# ...

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df.dtypes
# Out:
# mainbranch                         object
# employment                         object
# remotework                         object
# codingactivities                   object
# edlevel                            object
# learncode                          object
# learncodeonline                    object
# learncodecoursescert               object
# yearscode                          object
# yearscodepro                       object
# devtype                            object
# orgsize                            object
# purchaseinfluence                  object
# buynewtool                         object
# country                            object
# currency                           object
# comptotal                         float64
# compfreq                           object
# languagehaveworkedwith             object
# languagewanttoworkwith             object
# databasehaveworkedwith             object
# databasewanttoworkwith             object
# ...

# %%
df.sort_values(by=['country'], ascending=True, inplace=True)

# %%
df
# Out:
#                                                    mainbranch  \
# ResponseId
# 51189       I am not primarily a developer, but I write co...
# 38513                          I am a developer by profession
# 7945                                    I am learning to code
# 29705                                   I am learning to code
# 19202                          I am a developer by profession
# ...                                                       ...
# 73110                                           None of these
# 73158                                           None of these
# 73202                                           None of these
# 73216                                           None of these
# 73244                                           None of these
#
#                                                    employment    remotework  \
# ResponseId
# 51189                      Not employed, but looking for work           NaN
# ...

# %%
df.dropna(axis='columns',how='all')
# Out:
#                                                    mainbranch  \
# ResponseId
# 51189       I am not primarily a developer, but I write co...
# 38513                          I am a developer by profession
# 7945                                    I am learning to code
# 29705                                   I am learning to code
# 19202                          I am a developer by profession
# ...                                                       ...
# 73110                                           None of these
# 73158                                           None of these
# 73202                                           None of these
# 73216                                           None of these
# 73244                                           None of these
#
#                                                    employment    remotework  \
# ResponseId
# 51189                      Not employed, but looking for work           NaN
# ...

# %%
df.dropna(axis='index',how='any',subset=['country'])
# Out:
#                                                    mainbranch  \
# ResponseId
# 51189       I am not primarily a developer, but I write co...
# 38513                          I am a developer by profession
# 7945                                    I am learning to code
# 29705                                   I am learning to code
# 19202                          I am a developer by profession
# ...                                                       ...
# 71358                          I am a developer by profession
# 19594                          I am a developer by profession
# 24120                             I code primarily as a hobby
# 42449                                   I am learning to code
# 46152                          I am a developer by profession
#
#                                                    employment    remotework  \
# ResponseId
# 51189                      Not employed, but looking for work           NaN
# ...

# %%
df['country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: country, Length: 180, dtype: int64

# %%
df.columns
# Out:
# Index(['mainbranch', 'employment', 'remotework', 'codingactivities', 'edlevel',
#        'learncode', 'learncodeonline', 'learncodecoursescert', 'yearscode',
#        'yearscodepro', 'devtype', 'orgsize', 'purchaseinfluence', 'buynewtool',
#        'country', 'currency', 'comptotal', 'compfreq',
#        'languagehaveworkedwith', 'languagewanttoworkwith',
#        'databasehaveworkedwith', 'databasewanttoworkwith',
#        'platformhaveworkedwith', 'platformwanttoworkwith',
#        'webframehaveworkedwith', 'webframewanttoworkwith',
#        'misctechhaveworkedwith', 'misctechwanttoworkwith',
#        'toolstechhaveworkedwith', 'toolstechwanttoworkwith',
#        'newcollabtoolshaveworkedwith', 'newcollabtoolswanttoworkwith',
#        'opsysprofessional use', 'opsyspersonal use', 'versioncontrolsystem',
#        'vcinteraction', 'vchostingpersonal use', 'vchostingprofessional use',
#        'officestackasynchaveworkedwith', 'officestackasyncwanttoworkwith',
# ...

# %%
df['convertedcompyearly'].mean()
# Out:
# 170761.2778492816

# %%
df['convertedcompyearly'].median()
# Out:
# 67845.0

# %%
df.median()
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_2156\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# comptotal                    77500.0
# vchostingpersonal use            NaN
# vchostingprofessional use        NaN
# workexp                          8.0
# convertedcompyearly          67845.0
# dtype: float64

# %%
df.describe()
# Out:
#           comptotal  vchostingpersonal use  vchostingprofessional use  \
# count  3.842200e+04                    0.0                        0.0
# mean   2.342434e+52                    NaN                        NaN
# std    4.591478e+54                    NaN                        NaN
# min    0.000000e+00                    NaN                        NaN
# 25%    3.000000e+04                    NaN                        NaN
# 50%    7.750000e+04                    NaN                        NaN
# 75%    1.540000e+05                    NaN                        NaN
# max    9.000000e+56                    NaN                        NaN
#
#             workexp  convertedcompyearly
# count  36769.000000         3.807100e+04
# mean      10.242378         1.707613e+05
# std        8.706850         7.814132e+05
# min        0.000000         1.000000e+00
# 25%        4.000000         3.583200e+04
# 50%        8.000000         6.784500e+04
# 75%       15.000000         1.200000e+05
# ...

# %%
country_grp = df.groupby(['country'])

# %%
country_grp.get_group('Germany')
# Out:
#                                                    mainbranch  \
# ResponseId
# 21975                          I am a developer by profession
# 33741                          I am a developer by profession
# 28923                          I am a developer by profession
# 62482                          I am a developer by profession
# 5415        I am not primarily a developer, but I write co...
# ...                                                       ...
# 65680                          I am a developer by profession
# 1718                           I am a developer by profession
# 53399                          I am a developer by profession
# 12128       I am not primarily a developer, but I write co...
# 44315                          I am a developer by profession
#
#                                         employment  \
# ResponseId
# 21975                          Employed, full-time
# 33741                          Employed, full-time
# ...

# %%
country_grp.get_group('India')
# Out:
#                                 mainbranch  \
# ResponseId
# 58019       I am a developer by profession
# 63359       I am a developer by profession
# 6868           I code primarily as a hobby
# 63503                I am learning to code
# 32072       I am a developer by profession
# ...                                    ...
# 42174       I am a developer by profession
# 73137       I am a developer by profession
# 54644       I am a developer by profession
# 69315       I am a developer by profession
# 54646                I am learning to code
#
#                                                    employment  \
# ResponseId
# 58019                                     Employed, full-time
# 63359                                     Employed, full-time
# 6868                                       Student, part-time
# 63503                                     I prefer not to say
# 32072                                     Employed, full-time
# ...

# %%
country_grp['convertedcompyearly'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     93701.000000
# mean      228742.255908
# Name: Canada, dtype: float64

# %%
country_grp['convertedcompyearly'].agg(['median', 'mean']).loc['India']
# Out:
# median    18576.000000
# mean      51443.079613
# Name: India, dtype: float64

# %%
country_respondents = df['country'].value_counts()
country_respondents
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: country, Length: 180, dtype: int64

# %%
country_uses_python = country_grp['languagehaveworkedwith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# country
# Afghanistan                              25
# Albania                                  19
# Algeria                                  19
# Andorra                                   4
# Angola                                    3
#                                        ...
# Venezuela, Bolivarian Republic of...     52
# Viet Nam                                136
# Yemen                                     4
# Zambia                                    6
# Zimbabwe                                 11
# Name: languagehaveworkedwith, Length: 180, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Seychelles                                                1
# Monaco                                                    1
# Solomon Islands                                           1
# Burkina Faso                                              1
# Djibouti                                                  1
#
#                                                     languagehaveworkedwith
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
python_df['PctKnowsPython'] = (python_df['languagehaveworkedwith']/python_df['country']) * 100
python_df
# Out:
#                                                     country  \
# United States of America                              13543
# India                                                  6639
# Germany                                                5395
# United Kingdom of Great Britain and Northern Ir...     4190
# Canada                                                 2490
# ...                                                     ...
# Seychelles                                                1
# Monaco                                                    1
# Solomon Islands                                           1
# Burkina Faso                                              1
# Djibouti                                                  1
#
#                                                     languagehaveworkedwith  \
# United States of America                                              7017
# India                                                                 3081
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df
# Out:
#                        country  languagehaveworkedwith  PctKnowsPython
# Burkina Faso                 1                       1           100.0
# Solomon Islands              1                       1           100.0
# Saint Kitts and Nevis        1                       1           100.0
# Brunei Darussalam            1                       1           100.0
# Fiji                         2                       2           100.0
# ...                        ...                     ...             ...
# Antigua and Barbuda          2                       0             0.0
# San Marino                   1                       0             0.0
# Seychelles                   1                       0             0.0
# Monaco                       1                       0             0.0
# Djibouti                     1                       0             0.0
#
# [180 rows x 3 columns]

# %%
python_df.loc['India']
# Out:
# country                   6639.000000
# languagehaveworkedwith    3081.000000
# PctKnowsPython              46.407592
# Name: India, dtype: float64

# %%
python_df.loc['Japan']
# Out:
# country                   333.00000
# languagehaveworkedwith    165.00000
# PctKnowsPython             49.54955
# Name: Japan, dtype: float64
